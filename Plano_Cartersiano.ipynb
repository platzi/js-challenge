# %% [markdown]
# <a href="https://colab.research.google.com/github/rtrochepy/js-challenge/blob/main/Plano_Cartersiano.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# Coordenadas del punto
x = 2
y = 3

# Crear el gráfico del plano cartesiano
plt.figure(figsize=(6, 6))
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

# Graficar el punto
plt.plot(x, y, 'ro')  # 'ro' significa que se utilizará un punto rojo

# Etiquetar los ejes
plt.xlabel('Eje X')
plt.ylabel('Eje Y')

# Establecer límites de los ejes
plt.xlim(-5, 5)
plt.ylim(-5, 5)

# Mostrar el gráfico
plt.grid(color = 'gray', linestyle = '--', linewidth = 0.5)
plt.title('Plano Cartesiano')
plt.show()
